# %% [markdown]
# <a href="https://colab.research.google.com/github/GesielRodrigues/Curso_PMF/blob/main/PMF_M%C3%B3dulo_02_Manipula%C3%A7%C3%A3o_de_Dados_com_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><img src = "https://github.com/Trading-com-Dados/pmf/blob/main/logotipo-trading-com-dados.svg?raw=true" width = "200">

# %% [markdown]
# <center><img src = "https://github.com/Trading-com-Dados/pmf/blob/main/PMF%20002.png?raw=true" width = "700">

# %% [markdown]
# # **Módulo 02 - Manipulação de Dados com Python**

# %% [markdown]
# O objetivo deste módulo é dar início ao processo de transformação e processamento de dados utilizando a biblioteca Pandas. Assim, vamos deixar nossos dados no formato que precisamos antes de realizar as análises de mercado financeiro e construção de estratégias. Além disso, mostraremos como filtrar, modificar e juntar diferentes tipos de dados.
#
# Por fim, entraremos em conceitos de finanças quantitativas e mostraremos como obter e manipular dados de mercado financeiro usando diferentes bibliotecas.
#
# Este Módulo abrange as seguintes seções:

# %% [markdown]
# **1. Noções básicas da obtenção e processamento de dados**
#
# **2. Manipulação de dados**
#
# **3. Consolidação de dataframes**
#
# **4. Finanças quantitativas**

# %% [markdown]
# # **1. Noções básicas da obtenção e processamento de dados**

# %% [markdown]
# Para isso, vamos realizar a importação da biblioteca pandas, de uma forma semelhante ao que fizemos no módulo anterior.
#
# Inicialmente, vamos trabalhar com arquivos de dados, ou seja, dados não obtidos da web.
#
# Conheça a biblioteca Pandas:
# https://pandas.pydata.org/
#
# Sobre o Wes McKinney:
# https://wesmckinney.com/

# %% [markdown]
# **Baixando os arquivos necessários direto do Google Drive**

# %%
# !gdown https://drive.google.com/drive/folders/1IrYOftAa3dYorE8V3xFtdQ7cz2UHExec?usp=drive_link -O /content --folder
# Out:
# Retrieving folder list
# Processing file 1c_JGINOqVFbYFBafKlqS1mMyPkrJt2si Bovespa.csv
# Processing file 1bLeV03_81DYPeAo5cp4PEoEM9pQhul_E cotacoes_ibov.csv
# Processing file 1ILgc-Tit8MXrPz2J3v-ZR7cLSnrv0HMd cotacoes_pd_series.csv
# Processing file 1OU1XEv54N2i9m9H-0DLfSkqJfuMU9HeH PETR4_PROFIT.txt
# Processing file 1RVTONm5PqdNGS8lIss-4A9GiGhd7Ko4u PETR4.csv
# Processing file 1DKIY2NIBwqmze1A8fLN1jwF0jVLXQfMS PETR4.txt
# Processing file 1CChH69Mb0ZissjYaZ3SWehArko2TgJbJ PETR4.xlsx
# Processing file 18OC1gWxTZhq-udwZXLdp3JcJG0YKp0mj WIN_MT5.xlsx
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1c_JGINOqVFbYFBafKlqS1mMyPkrJt2si
# To: /content/Bovespa.csv
# 100% 370k/370k [00:00<00:00, 49.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1bLeV03_81DYPeAo5cp4PEoEM9pQhul_E
# To: /content/cotacoes_ibov.csv
# 100% 2.17M/2.17M [00:00<00:00, 138MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ILgc-Tit8MXrPz2J3v-ZR7cLSnrv0HMd
# To: /content/cotacoes_pd_series.csv
# 100% 76.8k/76.8k [00:00<00:00, 80.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OU1XEv54N2i9m9H-0DLfSkqJfuMU9HeH
# To: /content/PETR4_PROFIT.txt
# 100% 621k/621k [00:00<00:00, 82.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1RVTONm5PqdNGS8lIss-4A9GiGhd7Ko4u
# To: /content/PETR4.csv
# 100% 621k/621k [00:00<00:00, 99.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1DKIY2NIBwqmze1A8fLN1jwF0jVLXQfMS
# To: /content/PETR4.txt
# 100% 621k/621k [00:00<00:00, 44.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1CChH69Mb0ZissjYaZ3SWehArko2TgJbJ
# To: /content/PETR4.xlsx
# 100% 236k/236k [00:00<00:00, 107MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=18OC1gWxTZhq-udwZXLdp3JcJG0YKp0mj
# To: /content/WIN_MT5.xlsx
# 100% 31.5k/31.5k [00:00<00:00, 81.7MB/s]
# Download completed

# %% [markdown]
# Neste módulo vamos focar nossas atenções no poder da biblioteca pandas.
#
# Esta é a biblioteca de referência que devemos usar quando há necessidade abrir arquivos como .txt, .csv, .xlsx.

# %%
import pandas as pd

# %% [markdown]
# ## 1.1. Obtenção de dados via arquivos

# %% [markdown]
# Durante sua jornada no mundo dos dados você precisará trabalhar com diferentes tipos de arquivos e essa seção é dedicada para importação desses arquivos para o ambiente de análise em Python.

# %% [markdown]
# ### 1.1.1. Arquivos .csv

# %% [markdown]
# Durante sua jornada no mundo dos dados você precisará trabalhar com diferentes tipos de arquivos e essa seção é dedicada para importação desses arquivos para o ambiente de análise em Python.

# %%
pd.read_csv('PETR4.csv')
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2000-01-03   5.875000   5.875000   5.875000   5.875000   1.872027
# 1     2000-01-04   5.550000   5.550000   5.550000   5.550000   1.768469
# 2     2000-01-05   5.494000   5.494000   5.494000   5.494000   1.750625
# 3     2000-01-06   5.475000   5.475000   5.475000   5.475000   1.744570
# 4     2000-01-07   5.500000   5.500000   5.500000   5.500000   1.752536
# ...          ...        ...        ...        ...        ...        ...
# 5765  2022-12-13  24.100000  24.200001  23.309999  23.320000  23.320000
# 5766  2022-12-14  22.500000  22.600000  20.770000  21.469999  21.469999
# 5767  2022-12-15  21.000000  22.370001  20.830000  22.040001  22.040001
# 5768  2022-12-16  21.959999  22.110001  21.510000  22.049999  22.049999
# 5769  2022-12-19  22.100000  22.469999  21.639999  22.350000  22.350000
#
#            Volume
# 0     35389440000
# 1     28861440000
# 2     43033600000
# 3     34055680000
# 4     20912640000
# ...           ...
# 5765    102533100
# 5766    319501600
# 5767    132385600
# 5768     90767300
# 5769     37837300
#
# [5770 rows x 7 columns]

# %%
petr = pd.read_csv('PETR4.csv')

# %%
petr
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2000-01-03   5.875000   5.875000   5.875000   5.875000   1.872027
# 1     2000-01-04   5.550000   5.550000   5.550000   5.550000   1.768469
# 2     2000-01-05   5.494000   5.494000   5.494000   5.494000   1.750625
# 3     2000-01-06   5.475000   5.475000   5.475000   5.475000   1.744570
# 4     2000-01-07   5.500000   5.500000   5.500000   5.500000   1.752536
# ...          ...        ...        ...        ...        ...        ...
# 5765  2022-12-13  24.100000  24.200001  23.309999  23.320000  23.320000
# 5766  2022-12-14  22.500000  22.600000  20.770000  21.469999  21.469999
# 5767  2022-12-15  21.000000  22.370001  20.830000  22.040001  22.040001
# 5768  2022-12-16  21.959999  22.110001  21.510000  22.049999  22.049999
# 5769  2022-12-19  22.100000  22.469999  21.639999  22.350000  22.350000
#
#            Volume
# 0     35389440000
# 1     28861440000
# 2     43033600000
# 3     34055680000
# 4     20912640000
# ...           ...
# 5765    102533100
# 5766    319501600
# 5767    132385600
# 5768     90767300
# 5769     37837300
#
# [5770 rows x 7 columns]

# %%
type(petr)
# Out:
# pandas.core.frame.DataFrame

# %%
petr.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close       Volume
# 0  2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 1  2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2  2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 3  2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 4  2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %%
petr.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 5765  2022-12-13  24.100000  24.200001  23.309999  23.320000  23.320000
# 5766  2022-12-14  22.500000  22.600000  20.770000  21.469999  21.469999
# 5767  2022-12-15  21.000000  22.370001  20.830000  22.040001  22.040001
# 5768  2022-12-16  21.959999  22.110001  21.510000  22.049999  22.049999
# 5769  2022-12-19  22.100000  22.469999  21.639999  22.350000  22.350000
#
#          Volume
# 5765  102533100
# 5766  319501600
# 5767  132385600
# 5768   90767300
# 5769   37837300

# %%
petr['Close'].plot()
# Out:
# <Axes: >

# %%
petr.Close.plot();

# %% [markdown]
# ### 1.1.2. Arquivos .txt

# %%
data = pd.read_csv('PETR4.txt')

# %%
data.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close       Volume
# 0  2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 1  2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2  2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 3  2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 4  2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %% [markdown]
# **Estrutura de dataframes**
#
# As linhas, colunas representam um formato relacional.
#
# As colunas e linhas podem ser nomeadas com rótulos.

# %% [markdown]
# <center><img src = "https://pynative.com/wp-content/uploads/2021/02/dataframe.png" width = "700">

# %%
# Formato da data não reconhecido (dtype: object)

data['Date']
# Out:
# 0       2000-01-03
# 1       2000-01-04
# 2       2000-01-05
# 3       2000-01-06
# 4       2000-01-07
#            ...
# 5765    2022-12-13
# 5766    2022-12-14
# 5767    2022-12-15
# 5768    2022-12-16
# 5769    2022-12-19
# Name: Date, Length: 5770, dtype: object

# %%
data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
data.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close       Volume
# 0  2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 1  2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2  2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 3  2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 4  2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['Date']
# Out:
# 0      2000-01-03
# 1      2000-01-04
# 2      2000-01-05
# 3      2000-01-06
# 4      2000-01-07
#           ...
# 5765   2022-12-13
# 5766   2022-12-14
# 5767   2022-12-15
# 5768   2022-12-16
# 5769   2022-12-19
# Name: Date, Length: 5770, dtype: datetime64[ns]

# %% [markdown]
# Inspecionar novamente

# %%
data.head()
# Out:
#         Date   Open   High    Low  Close  Adj Close       Volume
# 0 2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 1 2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2 2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 3 2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 4 2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %% [markdown]
# Como transformamos a coluna 'Date' no index do dataframe?

# %%
data.index = data['Date']

# %% [markdown]
# Inspecionar novamente

# %%
data.head()
# Out:
#                  Date   Open   High    Low  Close  Adj Close       Volume
# Date
# 2000-01-03 2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 2000-01-04 2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2000-01-05 2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 2000-01-06 2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 2000-01-07 2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %% [markdown]
# Observe a diferença no eixo x

# %%
data.Close.plot();

# %% [markdown]
# Verificar o nome das colunas

# %%
lista = data.columns

# %%
lista
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# Verifica as dimensões do dataframe

# %%
data.shape
# Out:
# (5770, 7)

# %% [markdown]
# Verifica os tipos de dados por coluna

# %%
data.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %% [markdown]
# Qual foi o maior preço de PETR4?

# %% [markdown]
# Valor máximo da coluna

# %%
data.Close.max()
# Out:
# 52.5099983215332

# %% [markdown]
# Valor mínimo da coluna

# %%
data.Close.min()
# Out:
# 4.199999809265137

# %% [markdown]
# Podemos fazer isso para outras colunas

# %%
data.High.max()
# Out:
# 67.5

# %%
data.High.min()
# Out:
# 4.269999980926514

# %% [markdown]
# Valor médio de uma coluna

# %%
data.Close.mean()
# Out:
# 18.983105641882382

# %% [markdown]
# Valor da mediana?

# %%
data.Close.median()
# Out:
# 19.255000114440918

# %% [markdown]
# Valor da moda

# %%
data.Close.mode()
# Out:
# 0    23.5
# Name: Close, dtype: float64

# %% [markdown]
# Valor da variância

# %%
data.Close.var()
# Out:
# 91.58168462628566

# %% [markdown]
# Valor do desvio-padrão

# %%
data.Close.std()
# Out:
# 9.56983200616843

# %% [markdown]
# #### **Método pct_change()**

# %% [markdown]
# Método para calcular os retornos

# %%
data.head()
# Out:
#                  Date   Open   High    Low  Close  Adj Close       Volume
# Date
# 2000-01-03 2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 2000-01-04 2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2000-01-05 2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 2000-01-06 2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 2000-01-07 2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %%
retornos = data.Close.pct_change()

# %%
retornos
# Out:
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.055319
# 2000-01-05   -0.010090
# 2000-01-06   -0.003458
# 2000-01-07    0.004566
#                 ...
# 2022-12-13   -0.024676
# 2022-12-14   -0.079331
# 2022-12-15    0.026549
# 2022-12-16    0.000454
# 2022-12-19    0.013605
# Name: Close, Length: 5770, dtype: float64

# %% [markdown]
# Desvio padrão dos retornos

# %%
retornos.std()
# Out:
# 0.027025810844933572

# %% [markdown]
# Fiquem atentos quanto a diferença de Series com DataFrames

# %%
type(retornos)
# Out:
# pandas.core.series.Series

# %%
retornos_df = pd.DataFrame(retornos)

# %%
type(retornos_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Em muitos casos, o arquivo .txt pode apresentar uma formatação diferente do padrão usado no Python.
#
# Por exemplo, separador decimal como vírgula (, padrão no português) e não ponto (.)
#
# Nesses casos usamos diversos argumentos que auxiliam na leitura dos dados

# %% [markdown]
# Dados oriundos do PROFIT

# %%
petr_profit = pd.read_csv('PETR4_PROFIT.txt')
petr_profit
# Out:
#                                                                                           Date;Open;High;Low;Close;Adj Close;Volume
# 2000-01-03;5  875;5              875;5              875;5              875;1                            872026801109314;35389440000
# 2000-01-04;5  550000190734863;5  550000190734863;5  550000190734863;5  550000190734863;1               7684690952301025;28861440000
# 2000-01-05;5  49399995803833;5   49399995803833;5   49399995803833;5   49399995803833;1                7506250143051147;43033600000
# 2000-01-06;5  474999904632568;5  474999904632568;5  474999904632568;5  474999904632568;1               7445701360702515;34055680000
# 2000-01-07;5  5;5                5;5                5;5                5;1                             7525360584259033;20912640000
# ...                                                                                                                             ...
# 2022-12-13;24 100000381469727;24 200000762939453;23 309999465942383;23 31999969482422;23                   31999969482422;102533100
# 2022-12-14;22 5;22               600000381469727;20 770000457763672;21 469999313354492;21                 469999313354492;319501600
# 2022-12-15;21 0;22               3700008392334;20   829999923706055;22 040000915527344;22                 040000915527344;132385600
# 2022-12-16;21 959999084472656;22 110000610351562;21 510000228881836;22 049999237060547;22                  049999237060547;90767300
# 2022-12-19;22 100000381469727;22 469999313354492;21 639999389648438;22 350000381469727;22                  350000381469727;37837300
#
# [5770 rows x 1 columns]

# %% [markdown]
# Utilizando os parâmetros da função read_csv para reconhecer o data frame de forma correta
#
# Setnado o separador como ; e o separador decimal como ,

# %%
petr_profit = pd.read_csv('PETR4_PROFIT.txt', sep = ';', decimal = ',')

# %%
petr_profit.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close       Volume
# 0  2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 1  2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2  2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 3  2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 4  2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %%
petr_profit.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# ### 1.1.3. Arquivos .xlsx

# %% [markdown]
# Vamos abrir agora o arquivo Excel que contém uma amostra de dados intraday do minindice

# %%
win = pd.read_excel('WIN_MT5.xlsx')

# %%
win.head()
# Out:
#                  time    open    high     low   close  tick_volume  spread  \
# 0 2022-12-27 09:00:00  111175  111260  111065  111185        15490       1
# 1 2022-12-27 09:01:00  111190  111370  111180  111215        21014       1
# 2 2022-12-27 09:02:00  111215  111225  111030  111050        15905       1
# 3 2022-12-27 09:03:00  111055  111055  110920  110925        16948       1
# 4 2022-12-27 09:04:00  110930  111070  110915  111030        13465       1
#
#    real_volume ticker
# 0        30698   WIN$
# 1        42351   WIN$
# 2        30188   WIN$
# 3        32705   WIN$
# 4        24894   WIN$

# %%
win.dtypes
# Out:
# time           datetime64[ns]
# open                    int64
# high                    int64
# low                     int64
# close                   int64
# tick_volume             int64
# spread                  int64
# real_volume             int64
# ticker                 object
# dtype: object

# %% [markdown]
# Observe que nesse arquivo a coluna time já está como objeto datetime

# %%
win.index = win['time']

# %%
win.head()
# Out:
#                                    time    open    high     low   close  \
# time
# 2022-12-27 09:00:00 2022-12-27 09:00:00  111175  111260  111065  111185
# 2022-12-27 09:01:00 2022-12-27 09:01:00  111190  111370  111180  111215
# 2022-12-27 09:02:00 2022-12-27 09:02:00  111215  111225  111030  111050
# 2022-12-27 09:03:00 2022-12-27 09:03:00  111055  111055  110920  110925
# 2022-12-27 09:04:00 2022-12-27 09:04:00  110930  111070  110915  111030
#
#                      tick_volume  spread  real_volume ticker
# time
# 2022-12-27 09:00:00        15490       1        30698   WIN$
# 2022-12-27 09:01:00        21014       1        42351   WIN$
# 2022-12-27 09:02:00        15905       1        30188   WIN$
# 2022-12-27 09:03:00        16948       1        32705   WIN$
# 2022-12-27 09:04:00        13465       1        24894   WIN$

# %%
win.close.plot();

# %% [markdown]
# As funções para ler arquivos excel possuem diversos argumentos muito úteis, onde é possível já especificar o index, o cabeçalho, separador decimal (casos de txt e csv)...

# %%
win2 = pd.read_excel('WIN_MT5.xlsx', index_col = 0)

# %%
win2
# Out:
#                        open    high     low   close  tick_volume  spread  \
# time
# 2022-12-27 09:00:00  111175  111260  111065  111185        15490       1
# 2022-12-27 09:01:00  111190  111370  111180  111215        21014       1
# 2022-12-27 09:02:00  111215  111225  111030  111050        15905       1
# 2022-12-27 09:03:00  111055  111055  110920  110925        16948       1
# 2022-12-27 09:04:00  110930  111070  110915  111030        13465       1
# ...                     ...     ...     ...     ...          ...     ...
# 2022-12-27 18:20:00  110250  110270  110240  110265         1773       1
# 2022-12-27 18:21:00  110265  110400  110255  110340         4380       1
# 2022-12-27 18:22:00  110335  110350  110290  110310         1729       1
# 2022-12-27 18:23:00  110305  110340  110300  110325         1079       1
# 2022-12-27 18:24:00  110325  110340  110090  110090         1758       1
#
#                      real_volume ticker
# time
# 2022-12-27 09:00:00        30698   WIN$
# 2022-12-27 09:01:00        42351   WIN$
# 2022-12-27 09:02:00        30188   WIN$
# 2022-12-27 09:03:00        32705   WIN$
# 2022-12-27 09:04:00        24894   WIN$
# ...                          ...    ...
# 2022-12-27 18:20:00         4887   WIN$
# 2022-12-27 18:21:00        13118   WIN$
# 2022-12-27 18:22:00         3773   WIN$
# 2022-12-27 18:23:00         2206   WIN$
# 2022-12-27 18:24:00         8788   WIN$
#
# [565 rows x 8 columns]

# %%
win2.open.plot();

# %% [markdown]
# ## 1.2.Obtenção via bibliotecas/APIs

# %% [markdown]
# Vamos ver aqui exemplos de captura de dados de "fora", isto é, de fontes da Web, de plataformas famosas etc.
#
# Muito do processo de captura é feito de forma open-source por desenvolvedores individuais, ou seja, criam os projetos para fins particulares.
#
# Por causa disso, esses projetos tendem a ser descontinuados com o tempo.
#
# ATENÇÃO: as fontes aqui apresentadas podem e vão eventualmente apresentar algum erro ou problema, como: ficar fora do ar, não ter disponibilidade de dados para algum ativo, ter o código fonte removido do repositório central do Python, dentre outros.

# %% [markdown]
# Observe que, basicamente, o mundo dos conjuntos de dados das maiores fontes do mercado financeiro trabalham com dataframes

# %% [markdown]
# Autor: Ran Aroussi
#
# https://aroussi.com/

# %%
# Dados Yahoo Finance via biblioteca "yfinance"

# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.31)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.16.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2023.7.22)

# %%
import yfinance as yf

# %%
yf.download('ITUB4.SA', start = '2020-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  37.279999  38.029999  36.990002  38.029999  33.137745  20666100
# 2020-01-03  37.500000  38.240002  37.450001  37.630001  32.789215  24891400
# 2020-01-06  37.549999  37.580002  36.910000  37.070000  32.301243  22294700
# 2020-01-07  37.070000  37.240002  36.209999  36.209999  31.551886  20000900
# 2020-01-08  36.450001  36.810001  35.619999  35.619999  31.037777  25980900
# ...               ...        ...        ...        ...        ...       ...
# 2023-10-06  27.389999  28.290001  27.230000  27.900000  27.900000  44140600
# 2023-10-09  27.650000  27.750000  27.400000  27.660000  27.660000  14602500
# 2023-10-10  27.719999  28.049999  27.490000  27.629999  27.629999  24579700
# 2023-10-11  27.700001  28.020000  27.580000  27.980000  27.980000  15882400
# 2023-10-13  27.940001  28.090000  27.590000  27.860001  27.860001   8558700
#
# [942 rows x 6 columns]

# %%
itub4 = yf.download('ITUB4.SA', period = 'max')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
itub4.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2000-12-21  2.815505  2.988535  2.815174  2.960552   1.704615   74224
# 2000-12-22  2.930748  2.930748  2.814843  2.832229   1.630731   23312
# 2000-12-25  2.832229  2.832229  2.832229  2.832229   1.630731       0
# 2000-12-26  2.816664  2.834712  2.790006  2.831401   1.630254    7851
# 2000-12-27  2.881074  2.927437  2.831401  2.927437   1.685549   26996

# %%
itub4.Close.plot();

# %%
itub4[['Close','Adj Close']].plot();

# %% [markdown]
# Obtenção via APIs

# %% [markdown]
# O que é uma API?
# APIs são mecanismos que permitem que dois componentes de software se comuniquem usando um conjunto de definições e protocolos. Por exemplo, o sistema de software do instituto meteorológico contém dados meteorológicos diários. A aplicação para a previsão do tempo em seu telefone “fala” com esse sistema por meio de APIs e mostra atualizações meteorológicas diárias no telefone.
#
# https://aws.amazon.com/pt/what-is/api/

# %% [markdown]
# Dados do TradingView

# %%
# !pip install --upgrade --no-cache-dir git+https://github.com/rongardF/tvdatafeed.git
# Out:
# Collecting git+https://github.com/rongardF/tvdatafeed.git
#   Cloning https://github.com/rongardF/tvdatafeed.git to /tmp/pip-req-build-6x04v3b0
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed.git /tmp/pip-req-build-6x04v3b0
#   Resolved https://github.com/rongardF/tvdatafeed.git to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (67.7.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (1.5.3)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (1.6.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->tvdatafeed==2.1.0) (1.16.0)
# Building wheels for collected packages: tvdatafeed
#   Building wheel for tvdatafeed (setup.py) ... done
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17532 sha256=c6a612655a3be9838fc3330ff2a00aa5064f02e129883ede2503a1e168e337a4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k64g1q_i/wheels/4b/f9/e9/82474a5d9a64702ba7dd5481dee05d267c69bcfa480d382b7c
# Successfully built tvdatafeed
# Installing collected packages: tvdatafeed
# Successfully installed tvdatafeed-2.1.0

# %%
from tvDatafeed import TvDatafeed, Interval

# %%
tv = TvDatafeed()

lren = tv.get_hist(symbol = 'LREN3', exchange = 'BMFBOVESPA', interval=Interval.in_daily, n_bars=10000)
# Out:
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited

# %%
lren.tail()
# Out:
#                                symbol   open   high    low  close      volume
# datetime
# 2023-10-06 13:00:00  BMFBOVESPA:LREN3  12.43  12.72  12.09  12.59  23575200.0
# 2023-10-09 13:00:00  BMFBOVESPA:LREN3  12.40  12.84  12.15  12.68  20253400.0
# 2023-10-10 13:00:00  BMFBOVESPA:LREN3  12.87  13.10  12.77  13.00  22324400.0
# 2023-10-11 13:00:00  BMFBOVESPA:LREN3  13.10  13.21  12.93  13.10  21485700.0
# 2023-10-13 13:00:00  BMFBOVESPA:LREN3  13.02  13.06  12.72  12.83  11821100.0

# %%
lren['symbol']  = lren.symbol.str.replace('BMFBOVESPA:', '')

# %%
lren.tail()
# Out:
#                     symbol   open   high    low  close      volume
# datetime
# 2023-10-06 13:00:00  LREN3  12.43  12.72  12.09  12.59  23575200.0
# 2023-10-09 13:00:00  LREN3  12.40  12.84  12.15  12.68  20253400.0
# 2023-10-10 13:00:00  LREN3  12.87  13.10  12.77  13.00  22324400.0
# 2023-10-11 13:00:00  LREN3  13.10  13.21  12.93  13.10  21485700.0
# 2023-10-13 13:00:00  LREN3  13.02  13.06  12.72  12.83  11821100.0

# %% [markdown]
# ## 1.3. Dados estruturados e não-estruturados

# %%
# Exemplo de um dado estruturado

lren.head()
# Out:
#                     symbol       open       high        low      close  \
# datetime
# 2005-04-01 13:00:00  LREN3  14.297867  14.297867  14.297867  14.297867
# 2005-06-27 13:00:00  LREN3  19.063823  19.063823  19.063823  19.063823
# 2005-07-01 13:00:00  LREN3   0.105070   0.109292   0.105070   0.109292
# 2005-07-04 13:00:00  LREN3   0.110104   0.113514   0.109292   0.112215
# 2005-07-05 13:00:00  LREN3   0.112377   0.113514   0.107830   0.108967
#
#                            volume
# datetime
# 2005-04-01 13:00:00  2.433929e+02
# 2005-06-27 13:00:00  1.216965e+02
# 2005-07-01 13:00:00  4.418856e+08
# 2005-07-04 13:00:00  1.520983e+07
# 2005-07-05 13:00:00  5.249546e+07

# %%
# Dado não estruturado
# Exemplo: uma imagem é uma forma de dado não estruturado

# Entretanto, pode-se extrair informações relevantes mesmo nesse tipo de dado

from IPython.display import Image
Image(url ='https://upload.wikimedia.org/wikipedia/commons/a/ad/Lozingle_10032014.jpg')
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/ad/Lozingle_10032014.jpg"/>

# %% [markdown]
# Outros exemplos são páginas de internet, mensagens em aplicativos e redes sociais, áudios...

# %% [markdown]
# ## 1.4. Variáveis quantitativas e qualitativas

# %%
itub4
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2000-12-21   2.815505   2.988535   2.815174   2.960552   1.704615     74224
# 2000-12-22   2.930748   2.930748   2.814843   2.832229   1.630731     23312
# 2000-12-25   2.832229   2.832229   2.832229   2.832229   1.630731         0
# 2000-12-26   2.816664   2.834712   2.790006   2.831401   1.630254      7851
# 2000-12-27   2.881074   2.927437   2.831401   2.927437   1.685549     26996
# ...               ...        ...        ...        ...        ...       ...
# 2023-10-06  27.389999  28.290001  27.230000  27.900000  27.900000  44140600
# 2023-10-09  27.650000  27.750000  27.400000  27.660000  27.660000  14602500
# 2023-10-10  27.719999  28.049999  27.490000  27.629999  27.629999  24579700
# 2023-10-11  27.700001  28.020000  27.580000  27.980000  27.980000  15882400
# 2023-10-13  27.940001  28.090000  27.590000  27.850000  27.850000   8677700
#
# [5722 rows x 6 columns]

# %%
itub4.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# Variáveis dos tipos "float" e "int" são numéricas, ou seja, quantitativas.
#
# Para visualizar na prática um exemplo de variável quantitativa, mas realizar algumas transformações na tabela acima.

# %%
# Vamos mudar o formato dos dados acima

cotacoes_ativos_long = pd.melt(itub4, ignore_index= False)

# %%
cotacoes_ativos_long
# Out:
#            variable         value
# Date
# 2000-12-21     Open  2.815505e+00
# 2000-12-22     Open  2.930748e+00
# 2000-12-25     Open  2.832229e+00
# 2000-12-26     Open  2.816664e+00
# 2000-12-27     Open  2.881074e+00
# ...             ...           ...
# 2023-10-06   Volume  4.414060e+07
# 2023-10-09   Volume  1.460250e+07
# 2023-10-10   Volume  2.457970e+07
# 2023-10-11   Volume  1.588240e+07
# 2023-10-13   Volume  8.677700e+06
#
# [34332 rows x 2 columns]

# %% [markdown]
# Perceba que essa nova coluna "variable", que determina o tipo do dado, passou a ser uma variável qualitativa.

# %%
cotacoes_ativos_long.dtypes
# Out:
# variable     object
# value       float64
# dtype: object

# %% [markdown]
# Veja que a variável "variable" agora é do tipo "object", ou seja, é uma variável que possui textos (ou strings).
#
# Portanto, é uma variável qualitativa.

# %%
# Vamos usar a função de conjuntos para ver quais são as categorias dentro dessa variável qualitativa.

set(cotacoes_ativos_long.variable)
# Out:
# {'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'}

# %% [markdown]
# Perceba que antes essas eram as colunas do dataframe original.

# %%
itub4.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# ## 1.5. Alterando diretórios de acesso aos dados (nesse caso apenas em IDEs locais)

# %% [markdown]
# Podemos fazer algumas modificações e ajustes um pouco mais avançados. E se o arquivo não estiver na pasta onde está o código que você está criando?
#
# Primeiro verifique qual o endereço que o Python está "vendo" naquele momento

# %%
import os

# %%
caminho = os.getcwd()

# %%
caminho
# Out:
# '/content'

# %%
novo_caminho = caminho + '/' + "Meus Arquivos"

# %%
novo_caminho
# Out:
# '/content/Meus Arquivos'

# %% [markdown]
# E se quiséssemos mudar o diretório? Basta usar o seguinte comando:

# %%
os.chdir(novo_caminho)

# %% [markdown]
# Será que funcionou?

# %%
os.getcwd()
# Out:
# '/content/Meus Arquivos'
